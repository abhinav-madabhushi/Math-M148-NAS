# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from gym import Env
from gym.spaces import Discrete, Box
import numpy as np

# %%
# Define activations separately for indexing and instantiation
activation_names = ['sigmoid', 'tanh', 'relu', 'elu', 'selu', 'swish']
activation_map = {
    'sigmoid': nn.Sigmoid,
    'tanh': nn.Tanh,
    'relu': nn.ReLU,
    'elu': nn.ELU,
    'selu': nn.SELU,
    'swish': lambda: nn.SiLU(),  # swish ≈ SiLU in PyTorch
}

def decode_action(action_id):
    if 0 <= action_id <= 41:  # Dense Layer with some number of units
        units_list = [8, 16, 32, 64, 128, 256, 512]
        units_idx = action_id // len(activation_names)
        act_idx = action_id % len(activation_names)
        units = units_list[units_idx]
        activation_name = activation_names[act_idx]
        activation_fn = activation_map[activation_name]
        return ('dense', units, activation_name)  

    elif 42 <= action_id <= 44:  # Dropout layer
        dropout_rates = [0.0, 0.2, 0.5]
        return ('dropout', dropout_rates[action_id - 42])

    elif action_id == 45:  # BatchNorm layer
        return ('batchnorm',)

    elif action_id == 46:  # Stop building layers
        return ('stop',)

    else:
        raise ValueError(f"Invalid action id: {action_id}")

# %%
# make sure you understand how this is working and how the results are being logged.

# %%
class NASMLPEnv(Env):
    def __init__(self, dataset, max_layers=10):
        self.dataset = dataset  
        self.max_layers = max_layers
        self.action_space = Discrete(47)
        self.observation_space = Box(low=0, high=1, shape=((max_layers + 10) * 3,), dtype=np.float32)  # 3 inputs per layer, layer type, number of units, and activation function
        self.architecture = []
        self.done = False

        self.best_architecture = None
        self.best_reward = -float('inf')
        self.architecture_log = []

        self.max_parameters = self._estimate_max_parameters()

    def reset(self):
        if self.architecture:
            self.architecture_log.append({
                'architecture': list(self.architecture),
                'reward': 0,
                'accuracy': None,
                'complexity': None,
                'complexity_epochs': None,
                'completed': False,
                'termination_reason': 'incomplete'
            })
        self.architecture = []
        self.done = False
        return self._get_obs()

    def _estimate_max_parameters(self):
        input_dim = self.dataset[0].shape[1]  
        max_units = 512
        total_params = 0
    
        for _ in range(self.max_layers):
            total_params += input_dim * max_units + max_units  
            input_dim = max_units
    
        output_dim = self.dataset[1].shape[1]
        total_params += max_units * output_dim + output_dim
    
        return total_params


    def step(self, action_id):
        decoded = decode_action(action_id)

        dense_count = sum(1 for layer in self.architecture if layer[0] == 'dense')
        if decoded[0] == 'stop' or (decoded[0] == 'dense' and dense_count >= self.max_layers):
            self.done = True
            reward, acc, complexity, complexity_epochs = self._evaluate_model()  

            # Log architecture, reward, accuracy, and complexity
            self.architecture_log.append({
                'architecture': list(self.architecture),
                'reward': reward,
                'accuracy': acc,
                'complexity': complexity,
                'complexity_epochs': complexity_epochs,
                'completed': True,
                'termination_reason': 'stop' if decoded[0] == 'stop' else 'max_dense'
            })
        
    
            print(f"\n🎯 Final Architecture: {self.architecture}")
            print(f"🏆 Validation Accuracy (acc): {acc:.2f}%")
            print(f"⚙️  Complexity (number of layers): {complexity}")
            print(f"🏅 Reward (acc - penalty): {reward:.2f}%\n")
            print(f"🏅 Complexity (Number of epochs): {complexity_epochs:.2f}%\n")

            # Track best
            if reward > self.best_reward:
                self.best_reward = reward
                self.best_architecture = list(self.architecture)
                self.best_accuracy = acc  
                self.best_complexity = complexity 
                print(f"🌟 New Best Architecture Found with Reward: {reward:.2f}%")
        else:
            self.architecture.append(decoded)
            reward = 0

        return self._get_obs(), reward, self.done, {}

    def _get_obs(self):
        obs = np.zeros(self.observation_space.shape[0])
        for i, layer in enumerate(self.architecture):
            base = i * 3
            if layer[0] == 'dense':
                obs[base] = layer[1] / 512  # normalized units
                obs[base + 1] = activation_names.index(layer[2]) / (len(activation_names) - 1)
                obs[base + 2] = 0
            elif layer[0] == 'dropout':
                obs[base] = layer[1]
                obs[base + 1] = -1
                obs[base + 2] = 1
            elif layer[0] == 'batchnorm':
                obs[base] = -1
                obs[base + 1] = -1
                obs[base + 2] = 2
        return obs

    def _evaluate_model(self):
        X_train, y_train, X_val, y_val = self.dataset

        model = nn.Sequential()
        input_dim = X_train.shape[1]

        for i, layer in enumerate(self.architecture):
            if layer[0] == 'dense':
                model.add_module(f"fc{i}", nn.Linear(input_dim, layer[1]))
                model.add_module(f"act{i}", activation_map[layer[2]]())
                input_dim = layer[1]
            elif layer[0] == 'dropout':
                model.add_module(f"dropout{i}", nn.Dropout(p=layer[1]))
            elif layer[0] == 'batchnorm':
                model.add_module(f"bn{i}", nn.BatchNorm1d(input_dim))

        model.add_module("output", nn.Linear(input_dim, y_train.shape[1]))

        loss_fn = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=0.01) # can make the RL choose optimizer and LR also here
        train_loader = DataLoader(TensorDataset(X_train, y_train), batch_size=64, shuffle=True)

        best_acc = 0
        patience = 3
        patience_counter = 0
        max_epochs = 100
        epochs_used = 0
        model.train()
        for _ in range(max_epochs):  
            for xb, yb in train_loader:
                optimizer.zero_grad()
                output = model(xb)
                loss = loss_fn(output, yb)
                loss.backward()
                optimizer.step()
    
            # Early stopping check
            model.eval()
            with torch.no_grad():
                preds = model(X_val)
                acc = (preds.argmax(dim=1) == y_val.argmax(dim=1)).float().mean().item()
    
            epochs_used += 1
    
            if acc > best_acc + 1e-4:
                best_acc = acc
                patience_counter = 0
            else:
                patience_counter += 1
    
            if patience_counter >= patience:
                break

        no_of_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
        max_params = self._estimate_max_parameters()
        epochs_percentage = epochs_used*100/max_epochs
        alpha = 0.8
        #beta = 0.1

        reward = (alpha * acc * 100) + ((1 - alpha) * (100 - (no_of_params * epochs_used)/(max_params * max_epochs)))
        #reward = (alpha * acc * 100) + ((1 - alpha - beta) * (100 - (no_of_params*100/max_params))) + (beta * (100 - epochs_percentage))

        return reward, acc * 100, 100 - (no_of_params*100/max_params), (100 - epochs_percentage)
# Out:
#   Cell In[7], line 162
#     reward = (alpha * acc * 100) + ((1 - alpha) * (100 - (no_of_params * epochs_used)/(max_params * max_epochs))
#                                    ^
# SyntaxError: '(' was never closed

# %% [markdown]
# # Reward function ideas:
# - Something to do with epochs as well, some early stopping measure and then take the percentage of epochs: Done
# - Keep only accuracy and make a list of the top 10/15 and compare, and choose the simplest one - To do
# - Penalize time (instead of complexity) using a parameter lambda that is very small - To do

# %%
import pandas as pd
import torch
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from torch.nn.functional import one_hot

import openml
dataset = openml.datasets.get_dataset(23512)
X, y, _, _ = dataset.get_data(target=dataset.default_target_attribute)

df = pd.concat([X, y], axis=1)

df.dropna(inplace=True)

X = df.drop(columns=[dataset.default_target_attribute])
y = df[dataset.default_target_attribute]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

le = LabelEncoder()
y_encoded = le.fit_transform(y)  

y_oh = one_hot(torch.tensor(y_encoded)).float()

X_train_np, X_val_np, y_train_tensor, y_val_tensor = train_test_split(
    X_scaled, y_oh, test_size=0.1, random_state=42)

X_train_tensor = torch.tensor(X_train_np).float()
X_val_tensor = torch.tensor(X_val_np).float()

# %%
dataset = (X_train_tensor, y_train_tensor, X_val_tensor, y_val_tensor)

# %%
print(X_train_tensor.shape)  # [n_train, n_features]
print(y_train_tensor.shape)  # [n_train, 2]  (one-hot binary)
# Out:
# torch.Size([88244, 28])
# torch.Size([88244, 2])

# %%
# Pass into your NAS environment
env = NASMLPEnv(dataset=dataset, max_layers=10)

# %%
from stable_baselines3 import DQN

import time

start_time = time.time()

model = DQN(
    "MlpPolicy",
    env,
    gamma=0.99,                       
    exploration_initial_eps=1.0,     
    exploration_final_eps=0.05,      
    exploration_fraction=0.1,        
    verbose=1,
    tensorboard_log="./nas_logs/"
)

#model = DQN("MlpPolicy", env, verbose=1, tensorboard_log="./nas_logs/")
model.learn(total_timesteps=10000)

end_time = time.time()
elapsed_time = end_time - start_time
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Logging to ./nas_logs/DQN_36
#
# 🎯 Final Architecture: [('dense', 256, 'selu'), ('dense', 16, 'relu'), ('dense', 16, 'swish'), ('dense', 512, 'swish'), ('dense', 32, 'sigmoid'), ('dense', 256, 'selu'), ('dense', 16, 'selu'), ('dense', 32, 'sigmoid'), ('dense', 8, 'elu'), ('dense', 512, 'swish')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 97.64978077787087
# 🏅 Reward (acc - penalty): 62.02%
#
# 🏅 Complexity (Number of epochs): 96.00%
#
# 🌟 New Best Architecture Found with Reward: 62.02%
#
# 🎯 Final Architecture: [('dense', 256, 'selu'), ('dense', 16, 'elu'), ('dense', 32, 'selu'), ('dense', 16, 'relu'), ('dense', 512, 'selu'), ('dense', 16, 'sigmoid'), ('dense', 64, 'tanh'), ('dense', 8, 'selu'), ('dense', 8, 'elu'), ('dropout', 0.0), ('dense', 256, 'relu')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 98.57053893262312
# 🏅 Reward (acc - penalty): 62.11%
#
# 🏅 Complexity (Number of epochs): 96.00%
#
# 🌟 New Best Architecture Found with Reward: 62.11%
#
# 🎯 Final Architecture: [('dense', 128, 'swish'), ('dense', 128, 'selu'), ('dense', 64, 'selu'), ('dense', 64, 'relu'), ('dense', 128, 'tanh'), ('dense', 16, 'elu'), ('dense', 128, 'tanh'), ('dense', 512, 'tanh'), ('dense', 128, 'swish'), ('dense', 512, 'elu')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 89.74753107222607
# 🏅 Reward (acc - penalty): 61.23%
#
# 🏅 Complexity (Number of epochs): 96.00%
#
#
# 🎯 Final Architecture: [('dense', 8, 'relu'), ('dense', 128, 'elu'), ('dense', 64, 'tanh'), ('dense', 8, 'swish'), ('dense', 64, 'selu'), ('dense', 128, 'tanh'), ('dense', 8, 'selu'), ('dense', 128, 'elu'), ('dense', 256, 'sigmoid'), ('dense', 8, 'relu')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 97.63263632153924
# 🏅 Reward (acc - penalty): 62.02%
#
# 🏅 Complexity (Number of epochs): 96.00%
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 61.8     |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1        |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 45       |
# ----------------------------------
#
# 🎯 Final Architecture: [('dense', 512, 'selu'), ('dense', 16, 'sigmoid')]
# 🏆 Validation Accuracy (acc): 67.00%
# ⚙️  Complexity (number of layers): 99.02974142966276
# 🏅 Reward (acc - penalty): 72.80%
#
# 🏅 Complexity (Number of epochs): 93.00%
#
# 🌟 New Best Architecture Found with Reward: 72.80%
#
# 🎯 Final Architecture: [('dense', 16, 'relu'), ('dense', 32, 'tanh'), ('dense', 128, 'tanh'), ('dense', 512, 'tanh'), ('dense', 128, 'elu'), ('dense', 16, 'swish'), ('dense', 256, 'sigmoid'), ('dense', 16, 'sigmoid'), ('dense', 32, 'selu'), ('dense', 32, 'elu')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 93.73311292061696
# 🏅 Reward (acc - penalty): 61.63%
#
# 🏅 Complexity (Number of epochs): 96.00%
#
#
# 🎯 Final Architecture: [('dropout', 0.2), ('dense', 512, 'selu'), ('dense', 32, 'selu'), ('dense', 256, 'selu'), ('dense', 512, 'relu'), ('dense', 256, 'sigmoid'), ('dense', 256, 'swish'), ('dense', 32, 'relu'), ('dropout', 0.0), ('dense', 128, 'elu'), ('batchnorm',), ('dense', 32, 'tanh'), ('dense', 256, 'relu')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 83.43500948407792
# 🏅 Reward (acc - penalty): 60.60%
#
# 🏅 Complexity (Number of epochs): 96.00%
#
#
# 🎯 Final Architecture: [('dense', 256, 'swish'), ('dense', 128, 'sigmoid'), ('dense', 128, 'elu'), ('dense', 512, 'relu'), ('dense', 128, 'relu'), ('dense', 512, 'tanh'), ('dense', 64, 'elu'), ('dense', 8, 'relu'), ('dropout', 0.2), ('dense', 128, 'relu'), ('dense', 256, 'sigmoid')]
# 🏆 Validation Accuracy (acc): 46.68%
# ⚙️  Complexity (number of layers): 86.44268498994444
# 🏅 Reward (acc - penalty): 55.59%
#
# 🏅 Complexity (Number of epochs): 96.00%
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 62.3     |
# |    exploration_rate | 0.919    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1        |
# |    time_elapsed     | 79       |
# |    total_timesteps  | 85       |
# ----------------------------------
#
# 🎯 Final Architecture: [('dense', 16, 'elu'), ('dense', 256, 'relu'), ('dense', 64, 'selu'), ('dense', 8, 'relu'), ('dense', 32, 'swish'), ('dense', 32, 'swish'), ('dense', 16, 'elu'), ('dense', 16, 'sigmoid'), ('dense', 8, 'selu'), ('dense', 8, 'tanh')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 98.98503137687634
# 🏅 Reward (acc - penalty): 62.15%
#
# 🏅 Complexity (Number of epochs): 96.00%
#
#
# 🎯 Final Architecture: [('dense', 256, 'swish'), ('dense', 8, 'sigmoid'), ('dense', 16, 'swish'), ('batchnorm',), ('dense', 64, 'swish'), ('batchnorm',), ('dense', 8, 'sigmoid'), ('dense', 128, 'tanh'), ('dense', 16, 'relu'), ('dense', 128, 'tanh'), ('dense', 64, 'sigmoid'), ('dense', 512, 'elu')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 97.50623797681969
# 🏅 Reward (acc - penalty): 62.01%
#
# 🏅 Complexity (Number of epochs): 96.00%
#
#
# 🎯 Final Architecture: [('dense', 512, 'relu'), ('dense', 512, 'sigmoid'), ('dense', 256, 'sigmoid'), ('dense', 16, 'relu'), ('dense', 64, 'selu'), ('dense', 128, 'selu'), ('dense', 256, 'relu'), ('dense', 256, 'selu'), ('dense', 512, 'relu'), ('dense', 128, 'sigmoid')]
# 🏆 Validation Accuracy (acc): 46.68%
# ⚙️  Complexity (number of layers): 69.8007965448878
# 🏅 Reward (acc - penalty): 53.92%
#
# 🏅 Complexity (Number of epochs): 96.00%
#
#
# 🎯 Final Architecture: [('dense', 8, 'tanh'), ('dense', 128, 'elu'), ('dense', 64, 'swish'), ('dense', 16, 'tanh'), ('dense', 256, 'swish'), ('dense', 256, 'elu'), ('dense', 32, 'relu'), ('dense', 64, 'elu'), ('dense', 64, 'sigmoid'), ('dense', 32, 'swish')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 95.90440789014774
# 🏅 Reward (acc - penalty): 61.85%
#
# 🏅 Complexity (Number of epochs): 96.00%
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 61.5     |
# |    exploration_rate | 0.876    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1        |
# |    time_elapsed     | 120      |
# |    total_timesteps  | 131      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.19     |
# |    n_updates        | 7        |
# ----------------------------------
#
# 🎯 Final Architecture: [('dense', 256, 'tanh'), ('dense', 512, 'relu'), ('dense', 256, 'relu'), ('dropout', 0.2), ('dense', 128, 'selu'), ('dense', 256, 'sigmoid'), ('dense', 512, 'selu'), ('dense', 512, 'elu'), ('dense', 512, 'relu'), ('dense', 8, 'tanh'), ('dense', 64, 'relu')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 58.064911937163885
# 🏅 Reward (acc - penalty): 58.06%
#
# 🏅 Complexity (Number of epochs): 96.00%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 19
#       7 model = DQN(
#       8     "MlpPolicy",
#       9     env,
#    (...)
#      15     tensorboard_log="./nas_logs/"
#      16 )
#      18 #model = DQN("MlpPolicy", env, verbose=1, tensorboard_log="./nas_logs/")
# ---> 19 model.learn(total_timesteps=10000)
#      21 end_time = time.time()
#      22 elapsed_time = end_time - start_time
#
# File /opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/dqn/dqn.py:267, in DQN.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     258 def learn(
#     259     self: SelfDQN,
#     260     total_timesteps: int,
#    (...)
#     265     progress_bar: bool = False,
#     266 ) -> SelfDQN:
# --> 267     return super().learn(
#     268         total_timesteps=total_timesteps,
#     269         callback=callback,
#     270         log_interval=log_interval,
#     271         tb_log_name=tb_log_name,
#     272         reset_num_timesteps=reset_num_timesteps,
#     273         progress_bar=progress_bar,
#     274     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/off_policy_algorithm.py:328, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     325 assert isinstance(self.train_freq, TrainFreq)  # check done in _setup_learn()
#     327 while self.num_timesteps < total_timesteps:
# --> 328     rollout = self.collect_rollouts(
#     329         self.env,
#     330         train_freq=self.train_freq,
#     331         action_noise=self.action_noise,
#     332         callback=callback,
#     333         learning_starts=self.learning_starts,
#     334         replay_buffer=self.replay_buffer,
#     335         log_interval=log_interval,
#     336     )
#     338     if not rollout.continue_training:
#     339         break
#
# File /opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/off_policy_algorithm.py:560, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     557 actions, buffer_actions = self._sample_action(learning_starts, action_noise, env.num_envs)
#     559 # Rescale and perform action
# --> 560 new_obs, rewards, dones, infos = env.step(actions)
#     562 self.num_timesteps += env.num_envs
#     563 num_collected_steps += 1
#
# File /opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:222, in VecEnv.step(self, actions)
#     215 """
#     216 Step the environments with the given action
#     217
#     218 :param actions: the action
#     219 :return: observation, reward, done, information
#     220 """
#     221 self.step_async(actions)
# --> 222 return self.step_wait()
#
# File /opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:59, in DummyVecEnv.step_wait(self)
#      56 def step_wait(self) -> VecEnvStepReturn:
#      57     # Avoid circular imports
#      58     for env_idx in range(self.num_envs):
# ---> 59         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(  # type: ignore[assignment]
#      60             self.actions[env_idx]
#      61         )
#      62         # convert to SB3 VecEnv api
#      63         self.buf_dones[env_idx] = terminated or truncated
#
# File /opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# File /opt/anaconda3/lib/python3.12/site-packages/shimmy/openai_gym_compatibility.py:250, in GymV21CompatibilityV0.step(self, action)
#     241 def step(self, action: ActType) -> tuple[Any, float, bool, bool, dict]:
#     242     """Steps through the environment.
#     243
#     244     Args:
#    (...)
#     248         (observation, reward, terminated, truncated, info)
#     249     """
# --> 250     obs, reward, done, info = self.gym_env.step(action)
#     252     if self.render_mode is not None:
#     253         self.render()
#
# Cell In[7], line 52, in NASMLPEnv.step(self, action_id)
#      50 if decoded[0] == 'stop' or (decoded[0] == 'dense' and dense_count >= self.max_layers):
#      51     self.done = True
# ---> 52     reward, acc, complexity, complexity_epochs = self._evaluate_model()
#      54     # Log architecture, reward, accuracy, and complexity
#      55     self.architecture_log.append({
#      56         'architecture': list(self.architecture),
#      57         'reward': reward,
#    (...)
#      62         'termination_reason': 'stop' if decoded[0] == 'stop' else 'max_dense'
#      63     })
#
# Cell In[7], line 136, in NASMLPEnv._evaluate_model(self)
#     134     output = model(xb)
#     135     loss = loss_fn(output, yb)
# --> 136     loss.backward()
#     137     optimizer.step()
#     139 # Early stopping check
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/_tensor.py:626, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     616 if has_torch_function_unary(self):
#     617     return handle_torch_function(
#     618         Tensor.backward,
#     619         (self,),
#    (...)
#     624         inputs=inputs,
#     625     )
# --> 626 torch.autograd.backward(
#     627     self, gradient, retain_graph, create_graph, inputs=inputs
#     628 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/autograd/__init__.py:340, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     331 inputs = (
#     332     (inputs,)
#     333     if isinstance(inputs, (torch.Tensor, graph.GradientEdge))
#    (...)
#     336     else ()
#     337 )
#     339 grad_tensors_ = _tensor_or_tensors_to_tuple(grad_tensors, len(tensors))
# --> 340 grad_tensors_ = _make_grads(tensors, grad_tensors_, is_grads_batched=False)
#     341 if retain_graph is None:
#     342     retain_graph = create_graph
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/autograd/__init__.py:95, in _make_grads(outputs, grads, is_grads_batched)
#      93 new_grads: List[_OptionalTensor] = []
#      94 for out, grad in zip(outputs, grads):
# ---> 95     out = cast(Union[torch.Tensor, graph.GradientEdge], out)
#      96     out_size = None
#      97     out_device = None
#
# File /opt/anaconda3/lib/python3.12/typing.py:392, in _tp_cache.<locals>.decorator.<locals>.inner(*args, **kwds)
#     389 _cleanups.append(cache.cache_clear)
#     390 del cache
# --> 392 @functools.wraps(func)
#     393 def inner(*args, **kwds):
#     394     try:
#     395         return _caches[func](*args, **kwds)
#
# KeyboardInterrupt:

# %%
model.save("nas_agent_checkpoint_alpha_0.9_beta_0.1_23512")

# %%
# load previous model
# model = DQN.load("nas_agent_checkpoint")

# %%
# analyze the results

# %%
print(elapsed_time)

# %%
print(env.best_architecture)

# %%
# interesting result: look into it, pretty exciting

# %%
print(f"\n Best Reward: {env.best_reward:.2f}%")

# %%
print(f"\n Best Accuracy: {env.best_accuracy:.2f}%")

# %%
print(f"\n Best Complexity: {env.best_complexity:.2f}%")

# %%
print(f"\n Best Complexity Epochs: {env.best_complexity_epochs:.2f}%")

# %%
import pandas as pd

flat_data = []

for arch_id, run in enumerate(env.architecture_log):
    reward = run['reward']
    accuracy = run.get('accuracy', None)
    complexity = run.get('complexity', None)
    complexity_epochs = run.get('complexity_epochs', None)
    completed = run.get('completed', False)
    termination_reason = run.get('termination_reason', 'unknown')

    for i, layer in enumerate(run['architecture']):
        layer_type = layer[0]
        layer_info = {
            'arch_id': arch_id,
            'layer_num': i + 1,
            'layer_type': layer_type,
            'units': None,
            'activation': None,
            'dropout_rate': None,
            'reward': reward,
            'accuracy': accuracy,
            'complexity': complexity,
            'complexity_epochs': complexity_epochs,, 
            'completed': completed,
            'termination_reason': termination_reason
        }

        if layer_type == 'dense':
            layer_info['units'] = layer[1]
            layer_info['activation'] = layer[2]

        elif layer_type == 'dropout':
            layer_info['dropout_rate'] = layer[1]

        flat_data.append(layer_info)

# Create DataFrame and export to CSV
df = pd.DataFrame(flat_data)
df.to_csv("architecture_analysis_updated_alpha_0.9_beta_0.1.csv", index=False)

# %%
df = pd.read_csv("architecture_analysis_updated_alpha_0.9.csv")

# %%
# still needs to look at why there is only 6728 rows
df
# Out:
#       arch_id  layer_num layer_type  units activation  dropout_rate  \
# 0           0          1      dense    8.0      swish           NaN
# 1           0          2      dense  256.0      swish           NaN
# 2           0          3      dense   32.0       selu           NaN
# 3           0          4      dense  256.0        elu           NaN
# 4           0          5      dense   16.0      swish           NaN
# ...       ...        ...        ...    ...        ...           ...
# 7467     6862          2      dense   64.0       relu           NaN
# 7468     6862          3      dense  512.0        elu           NaN
# 7469     6863          1      dense    8.0       selu           NaN
# 7470     6863          2      dense   64.0       relu           NaN
# 7471     6863          3      dense  512.0        elu           NaN
#
#          reward   accuracy  complexity  completed termination_reason
# 0     47.520247  53.319734    4.675142       True          max_dense
# 1     47.520247  53.319734    4.675142       True          max_dense
# 2     47.520247  53.319734    4.675142       True          max_dense
# 3     47.520247  53.319734    4.675142       True          max_dense
# 4     47.520247  53.319734    4.675142       True          max_dense
# ...         ...        ...         ...        ...                ...
# 7467  61.296611  68.271291    1.475516       True               stop
# 7468  61.296611  68.271291    1.475516       True               stop
# 7469   0.000000        NaN         NaN      False         incomplete
# 7470   0.000000        NaN         NaN      False         incomplete
# 7471   0.000000        NaN         NaN      False         incomplete
#
# [7472 rows x 11 columns]

# %%
df[df['arch_id'] == 1]
# Out:
#     arch_id  layer_num layer_type  units activation  dropout_rate  reward  \
# 10        1          1      dense    8.0      swish           NaN     0.0
# 11        1          2      dense  256.0      swish           NaN     0.0
# 12        1          3      dense   32.0       selu           NaN     0.0
# 13        1          4      dense  256.0        elu           NaN     0.0
# 14        1          5      dense   16.0      swish           NaN     0.0
# 15        1          6      dense  256.0       relu           NaN     0.0
# 16        1          7      dense  256.0      swish           NaN     0.0
# 17        1          8      dense   64.0       relu           NaN     0.0
# 18        1          9      dense   16.0       relu           NaN     0.0
# 19        1         10      dense   16.0       tanh           NaN     0.0
#
#     accuracy  complexity  completed termination_reason
# 10       NaN         NaN      False         incomplete
# 11       NaN         NaN      False         incomplete
# 12       NaN         NaN      False         incomplete
# 13       NaN         NaN      False         incomplete
# 14       NaN         NaN      False         incomplete
# 15       NaN         NaN      False         incomplete
# 16       NaN         NaN      False         incomplete
# 17       NaN         NaN      False         incomplete
# 18       NaN         NaN      False         incomplete
# 19       NaN         NaN      False         incomplete

# %%
df[df['accuracy'].isna()].head(30)
# Out:
#     arch_id  layer_num layer_type  units activation  dropout_rate  reward  \
# 10        1          1      dense    8.0      swish           NaN     0.0
# 11        1          2      dense  256.0      swish           NaN     0.0
# 12        1          3      dense   32.0       selu           NaN     0.0
# 13        1          4      dense  256.0        elu           NaN     0.0
# 14        1          5      dense   16.0      swish           NaN     0.0
# 15        1          6      dense  256.0       relu           NaN     0.0
# 16        1          7      dense  256.0      swish           NaN     0.0
# 17        1          8      dense   64.0       relu           NaN     0.0
# 18        1          9      dense   16.0       relu           NaN     0.0
# 19        1         10      dense   16.0       tanh           NaN     0.0
# 32        3          1      dense   64.0      swish           NaN     0.0
# 33        3          2      dense   16.0       tanh           NaN     0.0
# 34        3          3      dense   64.0      swish           NaN     0.0
# 35        3          4  batchnorm    NaN        NaN           NaN     0.0
# 36        3          5      dense  512.0       selu           NaN     0.0
# 37        3          6      dense  512.0        elu           NaN     0.0
# 38        3          7      dense   64.0       selu           NaN     0.0
# 39        3          8    dropout    NaN        NaN           0.5     0.0
# 40        3          9      dense  256.0       selu           NaN     0.0
# 41        3         10      dense  512.0    sigmoid           NaN     0.0
# 42        3         11      dense   64.0       selu           NaN     0.0
# 43        3         12      dense   64.0    sigmoid           NaN     0.0
# 55        5          1      dense   16.0       selu           NaN     0.0
# 56        5          2      dense   64.0       relu           NaN     0.0
# 57        5          3    dropout    NaN        NaN           0.5     0.0
# 58        5          4      dense  256.0        elu           NaN     0.0
# 59        5          5      dense   64.0      swish           NaN     0.0
# 60        5          6      dense   64.0      swish           NaN     0.0
# 61        5          7      dense  512.0    sigmoid           NaN     0.0
# 62        5          8      dense  256.0        elu           NaN     0.0
#
#     accuracy  complexity  completed termination_reason
# 10       NaN         NaN      False         incomplete
# 11       NaN         NaN      False         incomplete
# 12       NaN         NaN      False         incomplete
# 13       NaN         NaN      False         incomplete
# 14       NaN         NaN      False         incomplete
# 15       NaN         NaN      False         incomplete
# 16       NaN         NaN      False         incomplete
# 17       NaN         NaN      False         incomplete
# 18       NaN         NaN      False         incomplete
# 19       NaN         NaN      False         incomplete
# 32       NaN         NaN      False         incomplete
# 33       NaN         NaN      False         incomplete
# 34       NaN         NaN      False         incomplete
# 35       NaN         NaN      False         incomplete
# 36       NaN         NaN      False         incomplete
# 37       NaN         NaN      False         incomplete
# 38       NaN         NaN      False         incomplete
# 39       NaN         NaN      False         incomplete
# 40       NaN         NaN      False         incomplete
# 41       NaN         NaN      False         incomplete
# 42       NaN         NaN      False         incomplete
# 43       NaN         NaN      False         incomplete
# 55       NaN         NaN      False         incomplete
# 56       NaN         NaN      False         incomplete
# 57       NaN         NaN      False         incomplete
# 58       NaN         NaN      False         incomplete
# 59       NaN         NaN      False         incomplete
# 60       NaN         NaN      False         incomplete
# 61       NaN         NaN      False         incomplete
# 62       NaN         NaN      False         incomplete

# %%
df.sort_values('accuracy', ascending = False).head(30)
# Out:
#       arch_id  layer_num layer_type  units activation  dropout_rate  \
# 6765      686          2      dense   64.0    sigmoid           NaN
# 6764      686          1      dense   64.0    sigmoid           NaN
# 6741      682          2      dense   64.0    sigmoid           NaN
# 6740      682          1      dense   64.0    sigmoid           NaN
# 6737      680          2      dense   64.0    sigmoid           NaN
# 6736      680          1      dense   64.0    sigmoid           NaN
# 6724      674          1      dense   64.0    sigmoid           NaN
# 6725      674          2      dense   64.0    sigmoid           NaN
# 6713      668          2      dense   64.0    sigmoid           NaN
# 6712      668          1      dense   64.0    sigmoid           NaN
# 6716      670          1      dense   64.0    sigmoid           NaN
# 6717      670          2      dense   64.0    sigmoid           NaN
# 7382     6105          1      dense  512.0    sigmoid           NaN
# 7146     3951          1      dense  128.0    sigmoid           NaN
# 6733      678          2      dense   64.0    sigmoid           NaN
# 6721      672          2      dense   64.0    sigmoid           NaN
# 6720      672          1      dense   64.0    sigmoid           NaN
# 6732      678          1      dense   64.0    sigmoid           NaN
# 6729      676          2      dense   64.0    sigmoid           NaN
# 6728      676          1      dense   64.0    sigmoid           NaN
# 7358     5810          1      dense  128.0    sigmoid           NaN
# 7056     2839          1      dense  128.0    sigmoid           NaN
# 7446     6688          1      dense  256.0    sigmoid           NaN
# 6960     1970          1      dense  512.0    sigmoid           NaN
# 7114     3646          1      dense  128.0    sigmoid           NaN
# 6946     1811          1      dense   32.0    sigmoid           NaN
# 7142     3893          1      dense  128.0    sigmoid           NaN
# 7212     4459          1      dense  512.0    sigmoid           NaN
# 7318     5387          1      dense   32.0    sigmoid           NaN
# 7192     4355          1      dense  256.0    sigmoid           NaN
#
#          reward   accuracy  complexity  completed termination_reason
# 6765  65.099110  72.361040    0.258259       True               stop
# 6764  65.099110  72.361040    0.258259       True               stop
# 6741  64.952248  72.197860    0.258259       True               stop
# 6740  64.952248  72.197860    0.258259       True               stop
# 6737  64.933886  72.177458    0.258259       True               stop
# 6736  64.933886  72.177458    0.258259       True               stop
# 6724  64.924708  72.167259    0.258259       True               stop
# 6725  64.924708  72.167259    0.258259       True               stop
# 6713  64.915529  72.157061    0.258259       True               stop
# 6712  64.915529  72.157061    0.258259       True               stop
# 6716  64.906351  72.146863    0.258259       True               stop
# 6717  64.906351  72.146863    0.258259       True               stop
# 7382  64.773682  72.044873    0.667037       True               stop
# 7146  64.814525  72.034675    0.166822       True               stop
# 6733  64.731953  71.953088    0.258259       True               stop
# 6721  64.731953  71.953088    0.258259       True               stop
# 6720  64.731953  71.953088    0.258259       True               stop
# 6732  64.731953  71.953088    0.258259       True               stop
# 6729  64.722769  71.942884    0.258259       True               stop
# 6728  64.722769  71.942884    0.258259       True               stop
# 7358  64.722735  71.932685    0.166822       True               stop
# 7056  64.612587  71.810299    0.166822       True               stop
# 7446  64.550021  71.759307    0.333561       True               stop
# 6960  64.498316  71.738911    0.667037       True               stop
# 7114  64.502439  71.687913    0.166822       True               stop
# 6946  64.496588  71.667516    0.041769       True               stop
# 7142  64.438190  71.616524    0.166822       True               stop
# 7212  64.333092  71.555328    0.667037       True               stop
# 7318  64.322185  71.473736    0.041769       True               stop
# 7192  64.283827  71.463537    0.333561       True               stop

# %%
df[df['accuracy'] < 60].head(100)
# Out:
#      arch_id  layer_num layer_type  units activation  dropout_rate     reward  \
# 0          0          1    dropout    NaN       None           0.5  34.325628
# 1          0          2      dense  512.0       selu           NaN  34.325628
# 2          0          3      dense  256.0       relu           NaN  34.325628
# 3          0          4      dense    8.0    sigmoid           NaN  34.325628
# 4          0          5      dense   64.0    sigmoid           NaN  34.325628
# ..       ...        ...        ...    ...        ...           ...        ...
# 192       20          9      dense  128.0      swish           NaN  40.241831
# 193       20         10  batchnorm    NaN       None           NaN  40.241831
# 194       20         11      dense  128.0       tanh           NaN  40.241831
# 228       24          1      dense  256.0    sigmoid           NaN  42.334732
# 229       24          2  batchnorm    NaN       None           NaN  42.334732
#
#       accuracy  complexity  completed termination_reason
# 0    46.680266   15.092920       True          max_dense
# 1    46.680266   15.092920       True          max_dense
# 2    46.680266   15.092920       True          max_dense
# 3    46.680266   15.092920       True          max_dense
# 4    46.680266   15.092920       True          max_dense
# ..         ...         ...        ...                ...
# 192  53.319734   12.069781       True               stop
# 193  53.319734   12.069781       True               stop
# 194  53.319734   12.069781       True               stop
# 228  53.319734    1.605276       True               stop
# 229  53.319734    1.605276       True               stop
#
# [100 rows x 11 columns]

# %%
df[df['arch_id'] == 8]
# Out:
#     arch_id  layer_num layer_type  units activation  dropout_rate     reward  \
# 84        8          1      dense   64.0      swish           NaN  42.346902
# 85        8          2      dense   16.0       relu           NaN  42.346902
# 86        8          3      dense   16.0    sigmoid           NaN  42.346902
# 87        8          4    dropout    NaN       None           0.0  42.346902
# 88        8          5      dense   64.0       relu           NaN  42.346902
# 89        8          6      dense   64.0      swish           NaN  42.346902
# 90        8          7      dense   16.0       selu           NaN  42.346902
# 91        8          8      dense  128.0    sigmoid           NaN  42.346902
# 92        8          9      dense   32.0       selu           NaN  42.346902
# 93        8         10      dense  128.0    sigmoid           NaN  42.346902
# 94        8         11      dense  128.0        elu           NaN  42.346902
# 95        8         12    dropout    NaN       None           0.2  42.346902
#
#      accuracy  complexity  completed termination_reason
# 84  53.319734     1.54443       True          max_dense
# 85  53.319734     1.54443       True          max_dense
# 86  53.319734     1.54443       True          max_dense
# 87  53.319734     1.54443       True          max_dense
# 88  53.319734     1.54443       True          max_dense
# 89  53.319734     1.54443       True          max_dense
# 90  53.319734     1.54443       True          max_dense
# 91  53.319734     1.54443       True          max_dense
# 92  53.319734     1.54443       True          max_dense
# 93  53.319734     1.54443       True          max_dense
# 94  53.319734     1.54443       True          max_dense
# 95  53.319734     1.54443       True          max_dense

# %%
df[df['layer_type'] == 'batchnorm']['accuracy'].mean()
# Out:
# 53.75438220798969

# %%
df[df['layer_type'] == 'dropout']['accuracy'].mean()
# Out:
# 56.00318891901365

# %%
df.groupby('activation')['accuracy'].mean()
# Out:
# activation
# elu        58.187054
# relu       59.291178
# selu       56.725523
# sigmoid    53.877449
# swish      58.579698
# tanh       55.326050
# Name: accuracy, dtype: float64

# %%
df.groupby('units')['accuracy'].mean()
# Out:
# units
# 8.0      53.862298
# 16.0     57.987943
# 32.0     59.184169
# 64.0     57.417682
# 128.0    59.076210
# 256.0    53.799047
# 512.0    58.109830
# Name: accuracy, dtype: float64

# %%
# analyze effect of different units in each layer
# analyze effect of different activation functions
# analyze the effect of different layers
