# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from gym import Env
from gym.spaces import Discrete, Box
import numpy as np

# %%
# Define activations separately for indexing and instantiation
activation_names = ['sigmoid', 'tanh', 'relu', 'elu', 'selu', 'swish']
activation_map = {
    'sigmoid': nn.Sigmoid,
    'tanh': nn.Tanh,
    'relu': nn.ReLU,
    'elu': nn.ELU,
    'selu': nn.SELU,
    'swish': lambda: nn.SiLU(),  # swish ≈ SiLU in PyTorch
}

def decode_action(action_id):
    if 0 <= action_id <= 41:  # Dense Layer with some number of units
        units_list = [8, 16, 32, 64, 128, 256, 512]
        units_idx = action_id // len(activation_names)
        act_idx = action_id % len(activation_names)
        units = units_list[units_idx]
        activation_name = activation_names[act_idx]
        activation_fn = activation_map[activation_name]
        return ('dense', units, activation_name)  

    elif 42 <= action_id <= 44:  # Dropout layer
        dropout_rates = [0.0, 0.2, 0.5]
        return ('dropout', dropout_rates[action_id - 42])

    elif action_id == 45:  # BatchNorm layer
        return ('batchnorm',)

    elif action_id == 46:  # Stop building layers
        return ('stop',)

    else:
        raise ValueError(f"Invalid action id: {action_id}")

# %%
def estimate_params(input_dim, output_dim, dense_layers=10, units=512):
    total_params = 0
    total_params += input_dim * max_units + max_units
    total_params += (max_dense_layers - 1) * (max_units * max_units + max_units)
    total_params += max_units * output_dim + output_dim
    return total_params

# %%
# maybe cap the number of dense layers instead of capping the number of layers: idea
# penalizing number of parameters

# %%
class NASMLPEnv(Env):
    def __init__(self, dataset, max_layers=10):
        self.dataset = dataset  
        self.max_parameters = self._estimate_max_parameters()
        self.max_layers = max_layers
        self.action_space = Discrete(47)
        self.observation_space = Box(low=0, high=1, shape=(max_layers * 3,), dtype=np.float32) # 3 inputs per layer, layer type, number of units, and activation function
        self.architecture = []
        self.done = False

        self.best_architecture = None
        self.best_reward = -float('inf')

        self.architecture_log = []

    def reset(self):
        self.architecture = []
        self.done = False
        return self._get_obs()

    def _estimate_max_parameters(self):
        input_dim = self.dataset[0].shape[1]  
        max_units = 512
        total_params = 0
    
        for _ in range(self.max_layers):
            total_params += input_dim * max_units + max_units  
            input_dim = max_units
    
        output_dim = self.dataset[1].shape[1]
        total_params += max_units * output_dim + output_dim
    
        return total_params


    def step(self, action_id):
        decoded = decode_action(action_id)

        dense_count = sum(1 for layer in self.architecture if layer[0] == 'dense')
        if decoded[0] == 'stop' or (decoded[0] == 'dense' and dense_count >= self.max_layers):
            self.done = True
            reward, acc, complexity = self._evaluate_model()  

            # Log architecture, reward, accuracy, and complexity
            self.architecture_log.append({
                'architecture': list(self.architecture),
                'reward': reward,
                'accuracy': acc,
                'complexity': complexity
            })
    
            print(f"\n🎯 Final Architecture: {self.architecture}")
            print(f"🏆 Validation Accuracy (acc): {acc:.2f}%")
            print(f"⚙️  Complexity (number of layers): {complexity}")
            print(f"🏅 Reward (acc - penalty): {reward:.2f}%\n")

            # Track best
            if reward > self.best_reward:
                self.best_reward = reward
                self.best_architecture = list(self.architecture)
                self.best_accuracy = acc  
                self.best_complexity = complexity 
                print(f"🌟 New Best Architecture Found with Reward: {reward:.2f}%")
        else:
            self.architecture.append(decoded)
            reward = 0

        return self._get_obs(), reward, self.done, {}

    def _get_obs(self):
        obs = np.zeros(self.observation_space.shape[0])
        for i, layer in enumerate(self.architecture):
            base = i * 3
            if layer[0] == 'dense':
                obs[base] = layer[1] / 512  # normalized units
                obs[base + 1] = activation_names.index(layer[2]) / (len(activation_names) - 1)
                obs[base + 2] = 0
            elif layer[0] == 'dropout':
                obs[base] = layer[1]
                obs[base + 1] = -1
                obs[base + 2] = 1
            elif layer[0] == 'batchnorm':
                obs[base] = -1
                obs[base + 1] = -1
                obs[base + 2] = 2
        return obs

    def _evaluate_model(self):
        X_train, y_train, X_val, y_val = self.dataset

        model = nn.Sequential()
        input_dim = X_train.shape[1]

        for i, layer in enumerate(self.architecture):
            if layer[0] == 'dense':
                model.add_module(f"fc{i}", nn.Linear(input_dim, layer[1]))
                model.add_module(f"act{i}", activation_map[layer[2]]())
                input_dim = layer[1]
            elif layer[0] == 'dropout':
                model.add_module(f"dropout{i}", nn.Dropout(p=layer[1]))
            elif layer[0] == 'batchnorm':
                model.add_module(f"bn{i}", nn.BatchNorm1d(input_dim))

        model.add_module("output", nn.Linear(input_dim, y_train.shape[1]))

        loss_fn = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=0.01) # can make the RL choose optimizer and LR also here
        train_loader = DataLoader(TensorDataset(X_train, y_train), batch_size=64, shuffle=True)

        model.train()
        for _ in range(10):  
            for xb, yb in train_loader:
                optimizer.zero_grad()
                output = model(xb)
                loss = loss_fn(output, yb)
                loss.backward()
                optimizer.step()

        model.eval()
        with torch.no_grad():
            preds = model(X_val)
            acc = (preds.argmax(dim=1) == y_val.argmax(dim=1)).float().mean().item()

        no_of_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
        max_params = self._estimate_max_parameters()
        alpha = 0.8 

        reward = (alpha * acc * 100) - ((1 - alpha) * (no_of_params*100/max_params))

        return reward, acc * 100, (no_of_params*100/max_params)

# %%
import pandas as pd
import torch
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from torch.nn.functional import one_hot

import openml
dataset = openml.datasets.get_dataset(42769)
X, y, _, _ = dataset.get_data(target=dataset.default_target_attribute)

df = pd.concat([X, y], axis=1)

df.dropna(inplace=True)

X = df.drop(columns=[dataset.default_target_attribute])
y = df[dataset.default_target_attribute]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

le = LabelEncoder()
y_encoded = le.fit_transform(y)  

y_oh = one_hot(torch.tensor(y_encoded)).float()

X_train_np, X_val_np, y_train_tensor, y_val_tensor = train_test_split(
    X_scaled, y_oh, test_size=0.1, random_state=42)

X_train_tensor = torch.tensor(X_train_np).float()
X_val_tensor = torch.tensor(X_val_np).float()

# %%
dataset = (X_train_tensor, y_train_tensor, X_val_tensor, y_val_tensor)

# %%
print(X_train_tensor.shape)  # [n_train, n_features]
print(y_train_tensor.shape)  # [n_train, 2]  (one-hot binary)
# Out:
# torch.Size([88244, 28])
# torch.Size([88244, 2])

# %%
# Pass into your NAS environment
# defining max layers as 10 since that is how we defined the penalty function
env = NASMLPEnv(dataset=dataset, max_layers=10)

# %%
from stable_baselines3 import DQN

import time

start_time = time.time()

model = DQN(
    "MlpPolicy",
    env,
    gamma=0.99,                       
    exploration_initial_eps=1.0,     
    exploration_final_eps=0.05,      
    exploration_fraction=0.1,        
    verbose=1,
    tensorboard_log="./nas_logs/"
)

#model = DQN("MlpPolicy", env, verbose=1, tensorboard_log="./nas_logs/")
model.learn(total_timesteps=1000)

end_time = time.time()
elapsed_time = end_time - start_time
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /opt/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Logging to ./nas_logs/DQN_18
#
# 🎯 Final Architecture: [('dense', 256, 'elu'), ('dense', 32, 'relu'), ('dense', 64, 'sigmoid'), ('dense', 32, 'elu'), ('dense', 64, 'relu'), ('dense', 512, 'sigmoid'), ('dense', 64, 'elu'), ('dense', 32, 'elu'), ('dense', 256, 'elu'), ('dense', 16, 'swish')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.99%
#
# 🌟 New Best Architecture Found with Reward: 14.99%
#
# 🎯 Final Architecture: [('dense', 512, 'tanh'), ('dense', 256, 'relu'), ('dense', 128, 'sigmoid'), ('dense', 64, 'swish'), ('dense', 128, 'sigmoid'), ('dense', 8, 'tanh'), ('dense', 64, 'selu'), ('dense', 64, 'selu'), ('dense', 512, 'swish'), ('dense', 32, 'tanh')]
# 🏆 Validation Accuracy (acc): 46.68%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 10.01%
#
#
# 🎯 Final Architecture: [('dense', 32, 'tanh'), ('dense', 64, 'swish'), ('dense', 64, 'selu'), ('dense', 16, 'elu'), ('dense', 64, 'tanh'), ('dense', 8, 'selu'), ('dense', 512, 'selu'), ('dense', 8, 'sigmoid'), ('dense', 32, 'relu'), ('dense', 64, 'selu')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.99%
#
#
# 🎯 Final Architecture: [('dense', 64, 'swish'), ('dense', 8, 'selu'), ('dense', 128, 'tanh'), ('dense', 8, 'tanh'), ('dense', 128, 'tanh'), ('dense', 256, 'swish'), ('dense', 64, 'elu'), ('dense', 128, 'relu'), ('dense', 8, 'sigmoid'), ('dense', 128, 'tanh')]
# 🏆 Validation Accuracy (acc): 50.62%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 12.96%
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 13.2     |
# |    exploration_rate | 0.582    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 3        |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 44       |
# ----------------------------------
#
# 🎯 Final Architecture: [('dense', 512, 'elu'), ('dense', 256, 'sigmoid'), ('dense', 64, 'swish'), ('dense', 16, 'swish'), ('dense', 32, 'elu'), ('dense', 32, 'swish'), ('dense', 8, 'selu'), ('dense', 256, 'tanh'), ('dense', 128, 'tanh'), ('dense', 32, 'selu')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.99%
#
#
# 🎯 Final Architecture: [('dense', 8, 'swish'), ('dense', 128, 'relu'), ('dense', 16, 'sigmoid'), ('dense', 256, 'elu'), ('dense', 8, 'sigmoid'), ('dense', 32, 'selu'), ('dense', 16, 'sigmoid'), ('dense', 128, 'tanh'), ('dense', 128, 'sigmoid'), ('dense', 128, 'selu')]
# 🏆 Validation Accuracy (acc): 46.68%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 10.01%
#
#
# 🎯 Final Architecture: [('dense', 16, 'selu'), ('dense', 32, 'sigmoid'), ('batchnorm',), ('dense', 32, 'sigmoid'), ('dense', 16, 'sigmoid'), ('dense', 64, 'relu'), ('dropout', 0.5), ('dense', 128, 'selu'), ('dense', 64, 'elu'), ('dense', 16, 'elu')]
# 🏆 Validation Accuracy (acc): 68.11%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 26.08%
#
# 🌟 New Best Architecture Found with Reward: 26.08%
#
# 🎯 Final Architecture: [('dense', 8, 'selu'), ('dense', 128, 'relu'), ('dense', 128, 'tanh'), ('dense', 128, 'relu'), ('dense', 64, 'swish'), ('dense', 8, 'tanh'), ('dense', 512, 'swish'), ('dense', 512, 'selu'), ('dense', 64, 'sigmoid'), ('dense', 64, 'elu')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.99%
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.164    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 3        |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 88       |
# ----------------------------------
#
# 🎯 Final Architecture: [('dense', 32, 'relu'), ('dense', 256, 'tanh'), ('dense', 16, 'swish'), ('dense', 8, 'selu'), ('dense', 256, 'sigmoid'), ('dense', 32, 'relu'), ('dense', 256, 'tanh'), ('dense', 32, 'relu'), ('dense', 64, 'tanh'), ('dense', 512, 'swish')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.99%
#
#
# 🎯 Final Architecture: [('dense', 256, 'relu'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.99%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.99%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'relu'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 46.68%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 10.01%
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 14.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 3        |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 132      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.67     |
# |    n_updates        | 7        |
# ----------------------------------
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 53.33%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 15.00%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 32, 'swish'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.99%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 32, 'selu'), ('dropout', 0.2), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 54.70%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 16.02%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 45.04%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 8.78%
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 3        |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 176      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.914    |
# |    n_updates        | 18       |
# ----------------------------------
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 50.43%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 12.83%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 55.16%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 16.37%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.99%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 54.92%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 16.19%
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 14.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 3        |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 220      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.24     |
# |    n_updates        | 29       |
# ----------------------------------
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 51.90%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 13.93%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 32, 'sigmoid'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.99%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 54.06%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 15.55%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.99%
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 14.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 3        |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 264      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.21     |
# |    n_updates        | 40       |
# ----------------------------------
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 32, 'elu')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.99%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 51.83%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 13.87%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 16, 'sigmoid'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.99%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 52.44%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.33%
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 14.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 3        |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 308      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.04     |
# |    n_updates        | 51       |
# ----------------------------------
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 53.62%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 15.21%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 49.01%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 11.75%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 46.16%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 9.62%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 51.56%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 13.67%
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 3        |
# |    time_elapsed     | 102      |
# |    total_timesteps  | 352      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.81     |
# |    n_updates        | 62       |
# ----------------------------------
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 45.29%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 8.97%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 55.57%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 16.68%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 47.91%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 10.94%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 47.60%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 10.70%
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 14       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 3        |
# |    time_elapsed     | 115      |
# |    total_timesteps  | 396      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.81     |
# |    n_updates        | 73       |
# ----------------------------------
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 52.19%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.14%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 48.96%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 11.72%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 52.10%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.07%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 51.62%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 13.71%
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 13.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 3        |
# |    time_elapsed     | 128      |
# |    total_timesteps  | 440      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.865    |
# |    n_updates        | 84       |
# ----------------------------------
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 54.84%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 16.13%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 48.06%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 11.04%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 50.77%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 13.08%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.99%
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 13.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 3        |
# |    time_elapsed     | 140      |
# |    total_timesteps  | 484      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.456    |
# |    n_updates        | 95       |
# ----------------------------------
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 53.66%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 15.24%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 512, 'relu'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 46.68%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 10.01%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 48.86%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 11.65%
#
#
# 🎯 Final Architecture: [('dense', 16, 'selu'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.99%
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 13.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 3        |
# |    time_elapsed     | 153      |
# |    total_timesteps  | 528      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.709    |
# |    n_updates        | 106      |
# ----------------------------------
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 53.07%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.81%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 51.45%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 13.59%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 53.34%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 15.01%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 51.26%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 13.44%
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 13.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 3        |
# |    time_elapsed     | 166      |
# |    total_timesteps  | 572      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.459    |
# |    n_updates        | 117      |
# ----------------------------------
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 32, 'selu'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 49.16%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 11.87%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 512, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 50.53%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 12.89%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 128, 'selu'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 48.13%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 11.10%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 256, 'tanh'), ('dense', 64, 'swish'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 52.61%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.45%
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 13.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 3        |
# |    time_elapsed     | 179      |
# |    total_timesteps  | 616      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.8      |
# |    n_updates        | 128      |
# ----------------------------------
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.99%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 8, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 44.83%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 8.63%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 47.06%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 10.29%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 51.90%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 13.93%
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 13.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 3        |
# |    time_elapsed     | 192      |
# |    total_timesteps  | 660      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.15     |
# |    n_updates        | 139      |
# ----------------------------------
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 128, 'relu')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.99%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 8, 'elu'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 52.46%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.35%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 16, 'elu'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 52.91%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.68%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.99%
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 13.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 3        |
# |    time_elapsed     | 205      |
# |    total_timesteps  | 704      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.799    |
# |    n_updates        | 150      |
# ----------------------------------
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 47.88%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 10.91%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 49.63%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 12.22%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 128, 'swish'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.99%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 512, 'relu'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 46.68%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 10.01%
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 13.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 3        |
# |    time_elapsed     | 219      |
# |    total_timesteps  | 748      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.933    |
# |    n_updates        | 161      |
# ----------------------------------
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 52.80%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.60%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'selu'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 49.96%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 12.47%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 256, 'relu'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.99%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 47.56%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 10.67%
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 13.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 3        |
# |    time_elapsed     | 232      |
# |    total_timesteps  | 792      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.772    |
# |    n_updates        | 172      |
# ----------------------------------
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 128, 'swish')]
# 🏆 Validation Accuracy (acc): 53.07%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.81%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 51.27%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 13.45%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 52.40%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.30%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'swish'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 47.76%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 10.82%
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 13.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 3        |
# |    time_elapsed     | 245      |
# |    total_timesteps  | 836      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.59     |
# |    n_updates        | 183      |
# ----------------------------------
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.99%
#
#
# 🎯 Final Architecture: [('dense', 16, 'selu'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 49.12%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 11.84%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 47.75%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 10.81%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.99%
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 13.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 3        |
# |    time_elapsed     | 258      |
# |    total_timesteps  | 880      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.687    |
# |    n_updates        | 194      |
# ----------------------------------
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 53.31%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.98%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.99%
#
#
# 🎯 Final Architecture: [('dense', 128, 'sigmoid'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.99%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 47.66%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 10.74%
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 13.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 3        |
# |    time_elapsed     | 271      |
# |    total_timesteps  | 924      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.774    |
# |    n_updates        | 205      |
# ----------------------------------
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'elu'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 53.31%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.98%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 46.01%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 9.51%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 48.60%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 11.45%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 50.84%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 13.13%
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 13.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 3        |
# |    time_elapsed     | 284      |
# |    total_timesteps  | 968      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.798    |
# |    n_updates        | 216      |
# ----------------------------------
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 48.96%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 11.72%
#
#
# 🎯 Final Architecture: [('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh'), ('dense', 64, 'tanh')]
# 🏆 Validation Accuracy (acc): 53.32%
# ⚙️  Complexity (number of layers): 100.0
# 🏅 Reward (acc - penalty): 14.99%

# %%
model.save("nas_agent_checkpoint_layers_penalty_0.25_23512")

# %%
# load previous model
# model = DQN.load("nas_agent_checkpoint")

# %%
# analyze the results

# %%
print(elapsed_time)
# Out:
# 291.69631910324097

# %%
print(env.best_architecture)
# Out:
# [('dense', 16, 'selu'), ('dense', 32, 'sigmoid'), ('batchnorm',), ('dense', 32, 'sigmoid'), ('dense', 16, 'sigmoid'), ('dense', 64, 'relu'), ('dropout', 0.5), ('dense', 128, 'selu'), ('dense', 64, 'elu'), ('dense', 16, 'elu')]

# %%
print(f"\n Best Reward: {env.best_reward:.2f}%")
# Out:
#  Best Validation Accuracy (Reward): 26.08%

# %%
print(f"\n Best Accuracy: {env.best_accuracy:.2f}%")
# Out:
#  Best Accuracy: 68.11%

# %%
print(f"\n Best Accuracy: {env.best_complexity:.2f}%")
# Out:
#  Best Accuracy: 100.00%

# %%
# Analyzing the different combinations
import pandas as pd

flat_data = []
for run in env.architecture_log:
    has_dropout = any(layer[0] == 'dropout' for layer in run['architecture'])
    has_batchnorm = any(layer[0] == 'batchnorm' for layer in run['architecture'])

    for layer in run['architecture']:
        if layer[0] == 'dense':
            flat_data.append({
                'units': layer[1],
                'activation': layer[2],
                'dropout': has_dropout,
                'batchnorm': has_batchnorm,
                'reward': run['reward']
            })
df = pd.DataFrame(flat_data)
df.to_csv("architecture_analysis.csv", index=False)

# %%
df
# Out:
#       units activation  dropout  batchnorm     reward
# 0         8       selu     True      False  69.476002
# 1       128       selu     True      False  69.476002
# 2       128       relu     True      False  69.476002
# 3       256      swish    False      False  47.049001
# 4        64      swish    False      False  47.049001
# ...     ...        ...      ...        ...        ...
# 2759    256       relu    False      False  73.479003
# 2760    256       relu    False      False  73.479003
# 2761    256       relu    False      False  73.479003
# 2762    256       relu    False      False  73.479003
# 2763    256       relu    False      False  73.479003
#
# [2764 rows x 5 columns]

# %%
df.groupby('activation')['reward'].mean()
# Out:
# activation
# elu        65.726087
# relu       66.170710
# selu       62.967862
# sigmoid    66.422900
# swish      63.449787
# tanh       68.310639
# Name: reward, dtype: float64

# %%
df.groupby('units')['reward'].mean()
# Out:
# units
# 8      66.939718
# 16     68.419237
# 32     66.783217
# 64     65.794753
# 128    63.441849
# 256    64.556628
# 512    62.063522
# Name: reward, dtype: float64

# %%
df.groupby('dropout')['reward'].mean()
# Out:
# dropout
# False    67.514510
# True     65.840581
# Name: reward, dtype: float64

# %%
df.groupby('batchnorm')['reward'].mean()

# %%
# analyze effect of different units in each layer
# analyze effect of different activation functions
# analyze the effect of different layers
